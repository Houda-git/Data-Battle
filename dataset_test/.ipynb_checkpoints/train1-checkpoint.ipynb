# %%
import numpy as np
import pandas as pd
import time

from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, brier_score_loss

TRAIN_PATH = "segment_alerts_all_airports_train.csv"
VALID_PATH = "dataset_set.csv"

df_train = pd.read_csv(TRAIN_PATH)
df_valid = pd.read_csv(VALID_PATH)

for df_ in [df_train, df_valid]:
    if "Unnamed: 0" in df_.columns:
        df_.drop(columns=["Unnamed: 0"], inplace=True, errors="ignore")
    df_["date"] = pd.to_datetime(df_["date"], utc=True)
    df_["icloud"] = df_["icloud"].astype(bool)

print("Train shape:", df_train.shape)
print("Valid shape:", df_valid.shape)

def month_to_season(m):
    if m in [12, 1, 2]:
        return "winter"
    elif m in [3, 4, 5]:
        return "spring"
    elif m in [6, 7, 8]:
        return "summer"
    else:
        return "autumn"


def add_base_columns(df, strong_cg_threshold=None):
    df = df.copy()

    df["is_cg"] = (~df["icloud"]).astype("int8")
    df["is_ic"] = df["icloud"].astype("int8")

    df["is_0_3"] = (df["dist"] < 3).astype("int8")
    df["is_3_10"] = ((df["dist"] >= 3) & (df["dist"] < 10)).astype("int8")
    df["is_10_20"] = ((df["dist"] >= 10) & (df["dist"] < 20)).astype("int8")
    df["is_20_30"] = ((df["dist"] >= 20) & (df["dist"] < 30)).astype("int8")

    df["amp_abs"] = df["amplitude"].abs()

    if strong_cg_threshold is None:
        strong_cg_threshold = df.loc[df["is_cg"] == 1, "amp_abs"].quantile(0.90)

    df["is_strong_cg"] = (
        (df["is_cg"] == 1) & (df["amp_abs"] >= strong_cg_threshold)
    ).astype("int8")

    df["hour"] = df["date"].dt.hour
    df["month"] = df["date"].dt.month
    df["dayofyear"] = df["date"].dt.dayofyear
    df["weekday"] = df["date"].dt.weekday

    df["season"] = df["month"].apply(month_to_season)
    df["is_summer"] = (df["season"] == "summer").astype("int8")
    df["is_peak_hour"] = df["hour"].between(12, 18).astype("int8")

    df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 24)
    df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 24)
    df["month_sin"] = np.sin(2 * np.pi * df["month"] / 12)
    df["month_cos"] = np.cos(2 * np.pi * df["month"] / 12)

    az_rad = np.deg2rad(df["azimuth"])
    df["azimuth_sin"] = np.sin(az_rad)
    df["azimuth_cos"] = np.cos(az_rad)

    az_bins = [0, 45, 90, 135, 180, 225, 270, 315, 360]
    az_labels = ["N", "NE", "E", "SE", "S", "SW", "W", "NW"]
    df["az_sector"] = pd.cut(
        df["azimuth"].mod(360),
        bins=az_bins,
        labels=az_labels,
        include_lowest=True,
        right=False
    )

    df["cg_amp_abs"] = np.where(df["is_cg"] == 1, df["amp_abs"], np.nan)

    return df, strong_cg_threshold


def build_timestamp_features(df_all):
    base = (
        df_all.groupby(["airport", "date"], as_index=False)
        .agg(
            n_total=("lightning_id", "size"),
            n_cg=("is_cg", "sum"),
            n_ic=("is_ic", "sum"),
            n_strong_cg=("is_strong_cg", "sum"),

            n_0_3=("is_0_3", "sum"),
            n_3_10=("is_3_10", "sum"),
            n_10_20=("is_10_20", "sum"),
            n_20_30=("is_20_30", "sum"),

            dist_min=("dist", "min"),
            dist_mean=("dist", "mean"),
            dist_max=("dist", "max"),

            amp_abs_mean=("amp_abs", "mean"),
            amp_abs_max=("amp_abs", "max"),
            amp_abs_sum=("amp_abs", "sum"),

            cg_amp_abs_mean=("cg_amp_abs", "mean"),
            cg_amp_abs_max=("cg_amp_abs", "max"),

            maxis_mean=("maxis", "mean"),
            azimuth_mean=("azimuth", "mean"),
            azimuth_sin_mean=("azimuth_sin", "mean"),
            azimuth_cos_mean=("azimuth_cos", "mean"),

            hour=("hour", "first"),
            month=("month", "first"),
            dayofyear=("dayofyear", "first"),
            weekday=("weekday", "first"),
            season=("season", "first"),
            is_summer=("is_summer", "first"),
            is_peak_hour=("is_peak_hour", "first"),
            hour_sin=("hour_sin", "first"),
            hour_cos=("hour_cos", "first"),
            month_sin=("month_sin", "first"),
            month_cos=("month_cos", "first"),
        )
        .sort_values(["airport", "date"])
        .reset_index(drop=True)
    )

    base["cg_amp_abs_mean"] = base["cg_amp_abs_mean"].fillna(0.0)
    base["cg_amp_abs_max"] = base["cg_amp_abs_max"].fillna(0.0)

    base["cg_ratio_now"] = np.where(base["n_total"] > 0, base["n_cg"] / base["n_total"], 0.0)
    base["strong_cg_ratio_now"] = np.where(base["n_cg"] > 0, base["n_strong_cg"] / base["n_cg"], 0.0)

    sector_counts = (
        df_all.groupby(["airport", "date", "az_sector"], observed=False)
        .size()
        .unstack(fill_value=0)
        .reset_index()
    )

    sector_cols = [c for c in sector_counts.columns if c not in ["airport", "date"]]
    sector_counts = sector_counts.rename(columns={c: f"sector_{c}_count" for c in sector_cols})

    base = base.merge(sector_counts, on=["airport", "date"], how="left")

    for c in base.columns:
        if c.startswith("sector_") and c.endswith("_count"):
            base[c] = base[c].fillna(0)

    return base


def add_since_features(base):
    parts = []

    for airport, g in base.groupby("airport"):
        g = g.sort_values("date").copy()

        g["delta_prev_min"] = g["date"].diff().dt.total_seconds().div(60).fillna(9999)

        def since_last(col_name, new_name):
            last_date = g["date"].where(g[col_name] > 0).ffill().shift()
            g[new_name] = (g["date"] - last_date).dt.total_seconds().div(60).fillna(9999)

        since_last("n_0_3", "since_last_0_3_min")
        since_last("n_3_10", "since_last_3_10_min")
        since_last("n_10_20", "since_last_10_20_min")
        since_last("n_20_30", "since_last_20_30_min")
        since_last("n_cg", "since_last_cg_min")
        since_last("n_strong_cg", "since_last_strong_cg_min")

        parts.append(g)

    return pd.concat(parts, ignore_index=True)


def add_rolling_features(base_time):
    windows = ["5min", "10min", "30min"]

    count_cols = [
        "n_total", "n_cg", "n_ic", "n_strong_cg",
        "n_0_3", "n_3_10", "n_10_20", "n_20_30"
    ]
    sector_cols = [c for c in base_time.columns if c.startswith("sector_") and c.endswith("_count")]
    count_cols_all = count_cols + sector_cols

    mean_cols = [
        "dist_min", "dist_mean", "dist_max",
        "amp_abs_mean", "amp_abs_max", "amp_abs_sum",
        "cg_amp_abs_mean", "cg_amp_abs_max",
        "cg_ratio_now", "strong_cg_ratio_now"
    ]

    parts = []

    for airport, g in base_time.groupby("airport"):
        g = g.sort_values("date").copy().set_index("date")
        out = g.copy()

        for w in windows:
            roll_sum = g[count_cols_all].rolling(w, closed="both").sum()
            roll_sum.columns = [f"{c}__sum_{w}" for c in roll_sum.columns]

            roll_mean = g[mean_cols].rolling(w, closed="both").mean()
            roll_mean.columns = [f"{c}__mean_{w}" for c in roll_mean.columns]

            out = pd.concat([out, roll_sum, roll_mean], axis=1)

        out = out.reset_index()
        parts.append(out)

    return pd.concat(parts, ignore_index=True)


def add_derived_features(features_all):
    eps = 1e-6
    df = features_all.copy()

    df["trend_total_5_vs_10"] = df["n_total__sum_5min"] / (df["n_total__sum_10min"] + eps)
    df["trend_0_3_5_vs_10"] = df["n_0_3__sum_5min"] / (df["n_0_3__sum_10min"] + eps)
    df["trend_10_20_5_vs_10"] = df["n_10_20__sum_5min"] / (df["n_10_20__sum_10min"] + eps)
    df["trend_20_30_5_vs_10"] = df["n_20_30__sum_5min"] / (df["n_20_30__sum_10min"] + eps)
    df["trend_cg_5_vs_10"] = df["n_cg__sum_5min"] / (df["n_cg__sum_10min"] + eps)

    df["far_vs_near_5min"] = (df["n_20_30__sum_5min"] + 1) / (df["n_0_3__sum_5min"] + df["n_3_10__sum_5min"] + 1)
    df["far_vs_near_10min"] = (df["n_20_30__sum_10min"] + 1) / (df["n_0_3__sum_10min"] + df["n_3_10__sum_10min"] + 1)
    df["far_vs_mid_10min"] = (df["n_20_30__sum_10min"] + 1) / (df["n_10_20__sum_10min"] + 1)
    df["mid_vs_near_10min"] = (df["n_10_20__sum_10min"] + 1) / (df["n_0_3__sum_10min"] + df["n_3_10__sum_10min"] + 1)

    df["dist_range_now"] = df["dist_max"] - df["dist_min"]
    df["dist_range_10min"] = df["dist_max__mean_10min"] - df["dist_min__mean_10min"]
    df["dist_drift_5_10"] = df["dist_mean__mean_5min"] - df["dist_mean__mean_10min"]

    df["severity_now"] = (
        0.4 * np.tanh(df["amp_abs_mean"] / 20.0) +
        0.4 * df["cg_ratio_now"] +
        0.2 * (1 - np.clip(df["dist_mean"] / 30.0, 0, 1))
    )

    for w in ["5min", "10min", "30min"]:
        df[f"severity_{w}"] = (
            0.4 * np.tanh(df[f"amp_abs_mean__mean_{w}"] / 20.0) +
            0.4 * df[f"cg_ratio_now__mean_{w}"] +
            0.2 * (1 - np.clip(df[f"dist_mean__mean_{w}"] / 30.0, 0, 1))
        )

    df["strong_cg_ratio_10min"] = df["n_strong_cg__sum_10min"] / (df["n_cg__sum_10min"] + eps)
    df["strong_cg_ratio_30min"] = df["n_strong_cg__sum_30min"] / (df["n_cg__sum_30min"] + eps)

    return df

def compute_target_safe_to_end(df_feat, danger_dist_km=20):
    labeled = df_feat[df_feat["airport_alert_id"].notna()].copy()

    rows = []
    for (airport, alert_id), g in labeled.groupby(["airport", "airport_alert_id"]):
        g = g.sort_values("date").copy()
        times = g[["date"]].drop_duplicates().sort_values("date").copy()
        t = times["date"].to_numpy()

        dangerous_times = np.array(sorted(g.loc[g["dist"] < danger_dist_km, "date"].unique()))
        idx = np.searchsorted(dangerous_times, t, side="right")

        times["safe_to_end_now"] = (idx == len(dangerous_times)).astype("int8")
        times["airport"] = airport
        times["airport_alert_id"] = alert_id
        rows.append(times)

    return pd.concat(rows, ignore_index=True), labeled

def compute_alert_life(df_with_alerts):
    tmp = df_with_alerts[df_with_alerts["airport_alert_id"].notna()].copy()
    tmp = tmp.sort_values(["airport", "airport_alert_id", "date"]).copy()

    life_parts = []
    for (airport, alert_id), g in tmp.groupby(["airport", "airport_alert_id"]):
        g = g.sort_values("date").copy()

        g["elapsed_since_alert_start_min"] = (g["date"] - g["date"].iloc[0]).dt.total_seconds().div(60)
        g["cum_lightnings"] = np.arange(1, len(g) + 1)
        g["cum_cg"] = g["is_cg"].cumsum()
        g["cum_ic"] = g["is_ic"].cumsum()
        g["cum_strong_cg"] = g["is_strong_cg"].cumsum()

        g["cum_avg_rate"] = g["cum_lightnings"] / (g["elapsed_since_alert_start_min"] + 1)
        g["cum_cg_rate"] = g["cum_cg"] / (g["elapsed_since_alert_start_min"] + 1)
        g["cum_strong_cg_rate"] = g["cum_strong_cg"] / (g["elapsed_since_alert_start_min"] + 1)

        g_ts = (
            g.groupby(["airport", "airport_alert_id", "date"], as_index=False)
            .agg(
                elapsed_since_alert_start_min=("elapsed_since_alert_start_min", "max"),
                cum_lightnings=("cum_lightnings", "max"),
                cum_cg=("cum_cg", "max"),
                cum_ic=("cum_ic", "max"),
                cum_strong_cg=("cum_strong_cg", "max"),
                cum_avg_rate=("cum_avg_rate", "max"),
                cum_cg_rate=("cum_cg_rate", "max"),
                cum_strong_cg_rate=("cum_strong_cg_rate", "max"),
            )
        )

        life_parts.append(g_ts)

    return pd.concat(life_parts, ignore_index=True)


def compute_airport_static(df_train_feat):
    labeled = df_train_feat[df_train_feat["airport_alert_id"].notna()].copy()

    alerts_stats = (
        labeled.groupby(["airport", "airport_alert_id"], as_index=False)
        .agg(
            alert_start=("date", "min"),
            alert_end=("date", "max"),
            n_lightnings_alert=("lightning_id", "count"),
            n_cg_alert=("is_cg", "sum"),
            n_ic_alert=("is_ic", "sum"),
            mean_amp_alert=("amp_abs", "mean"),
        )
    )

    alerts_stats["alert_duration_min"] = (
        alerts_stats["alert_end"] - alerts_stats["alert_start"]
    ).dt.total_seconds().div(60)

    airport_static = (
        alerts_stats.groupby("airport", as_index=False)
        .agg(
            airport_alert_duration_mean=("alert_duration_min", "mean"),
            airport_alert_duration_median=("alert_duration_min", "median"),
            airport_alert_n_lightnings_mean=("n_lightnings_alert", "mean"),
            airport_alert_n_lightnings_median=("n_lightnings_alert", "median"),
            airport_alert_cg_mean=("n_cg_alert", "mean"),
            airport_alert_ic_mean=("n_ic_alert", "mean"),
            airport_alert_amp_mean=("mean_amp_alert", "mean"),
        )
    )

    return airport_static
# Out:
# Train shape: (507071, 13)
# Valid shape: (183945, 13)

# %%
from sklearn.model_selection import ParameterGrid, TimeSeriesSplit
def temporal_cv_hyperparam_search(
    model_df_train,
    target_col="safe_to_end_now",
    drop_cols=None,
    optional_drop_cols=None,
    n_splits=5,
    param_grid=None,
):
    if drop_cols is None:
        drop_cols = [target_col, "date", "airport_alert_id"]
    if optional_drop_cols is None:
        optional_drop_cols = ["lightning_id"]

    if param_grid is None:
        param_grid = {
            "n_estimators": [200, 400],
            "learning_rate": [0.03, 0.05],
            "num_leaves": [15, 31],
            "max_depth": [6, -1],
            "min_child_samples": [20, 50],
            "subsample": [0.8, 1.0],
            "colsample_bytree": [0.8, 1.0],
            "reg_alpha": [0.0, 0.5],
            "reg_lambda": [0.0, 1.0],
            "class_weight": [None, "balanced"],
        }

    df_cv = model_df_train.sort_values(["date", "airport"]).reset_index(drop=True).copy()

    X = df_cv.drop(
        columns=[c for c in drop_cols + optional_drop_cols if c in df_cv.columns],
        errors="ignore"
    ).copy()
    y = df_cv[target_col].astype(int).copy()

    cat_cols = X.select_dtypes(include=["object", "category"]).columns.tolist()
    for c in cat_cols:
        X[c] = X[c].astype("category")

    tscv = TimeSeriesSplit(n_splits=n_splits)

    results = []
    best_score = -np.inf
    best_params = None

    all_params = list(ParameterGrid(param_grid))
    print(f"Nombre de combinaisons testées : {len(all_params)}")

    for i, params in enumerate(all_params, 1):
        fold_auc = []
        fold_ap = []
        fold_brier = []

        print(f"\n[{i}/{len(all_params)}] Test params: {params}")

        for fold, (train_idx, val_idx) in enumerate(tscv.split(X), 1):
            X_tr = X.iloc[train_idx].copy()
            y_tr = y.iloc[train_idx].copy()

            X_va = X.iloc[val_idx].copy()
            y_va = y.iloc[val_idx].copy()

            for c in cat_cols:
                if c in X_tr.columns:
                    X_tr[c] = X_tr[c].astype("category")
                if c in X_va.columns:
                    X_va[c] = X_va[c].astype("category")

            model = LGBMClassifier(
                objective="binary",
                random_state=42,
                n_jobs=-1,
                **params
            )

            model.fit(
                X_tr,
                y_tr,
                categorical_feature=cat_cols if len(cat_cols) > 0 else "auto",
            )

            p_va = model.predict_proba(X_va)[:, 1]

            auc = roc_auc_score(y_va, p_va)
            ap = average_precision_score(y_va, p_va)
            brier = brier_score_loss(y_va, p_va)

            fold_auc.append(auc)
            fold_ap.append(ap)
            fold_brier.append(brier)

            print(
                f"  Fold {fold} | AUC={auc:.4f} | AP={ap:.4f} | Brier={brier:.4f}"
            )

        mean_auc = float(np.mean(fold_auc))
        mean_ap = float(np.mean(fold_ap))
        mean_brier = float(np.mean(fold_brier))

        results.append({
            **params,
            "mean_auc": mean_auc,
            "mean_ap": mean_ap,
            "mean_brier": mean_brier,
        })

        print(
            f"--> Moyennes | AUC={mean_auc:.4f} | AP={mean_ap:.4f} | Brier={mean_brier:.4f}"
        )

        # Critère principal : AP, puis AUC
        score = mean_ap + 0.1 * mean_auc - 0.05 * mean_brier

        if score > best_score:
            best_score = score
            best_params = params.copy()

    results_df = pd.DataFrame(results).sort_values(
        ["mean_ap", "mean_auc", "mean_brier"],
        ascending=[False, False, True]
    ).reset_index(drop=True)

    return best_params, results_df

# %%
param_grid = {
    "n_estimators": [200, 400, 700],
    "learning_rate": [0.03, 0.05],
    "num_leaves": [15, 31],
    "max_depth": [6, -1],
    "min_child_samples": [20, 50],
    "subsample": [0.8],
    "colsample_bytree": [0.8],
    "reg_alpha": [0.0],
    "reg_lambda": [0.0, 1.0],
    "class_weight": [None, "balanced"],
}

best_params, cv_results = temporal_cv_hyperparam_search(
    model_df_train=model_df_train,
    target_col="safe_to_end_now",
    drop_cols=DROP_COLS,
    optional_drop_cols=OPTIONAL_DROP_COLS,
    n_splits=5,
    param_grid=param_grid,
)

print("\nMeilleurs hyperparamètres trouvés :")
print(best_params)

print("\nTop 10 résultats CV :")
print(cv_results.head(10))

cv_results.to_csv("cv_results_lgbm.csv", index=False)
# Out:
# Nombre de combinaisons testées : 192
#
# [1/192] Test params: {'class_weight': None, 'colsample_bytree': 0.8, 'learning_rate': 0.03, 'max_depth': 6, 'min_child_samples': 20, 'n_estimators': 200, 'num_leaves': 15, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.
192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 400, 'num_leaves': 15, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9446 | AP=0.3985 | Brier=0.0458
#   Fold 2 | AUC=0.9461 | AP=0.4532 | Brier=0.0437
#   Fold 3 | AUC=0.9247 | AP=0.3926 | Brier=0.0806
#   Fold 4 | AUC=0.9406 | AP=0.3720 | Brier=0.0748
#   Fold 5 | AUC=0.9242 | AP=0.3931 | Brier=0.0755
# --> Moyennes | AUC=0.9360 | AP=0.4019 | Brier=0.0641
#
# [186/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 400, 'num_leaves': 15, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9459 | AP=0.4028 | Brier=0.0467
#   Fold 2 | AUC=0.9460 | AP=0.4548 | Brier=0.0445
#   Fold 3 | AUC=0.9239 | AP=0.3965 | Brier=0.0819
#   Fold 4 | AUC=0.9409 | AP=0.3710 | Brier=0.0758
#   Fold 5 | AUC=0.9247 | AP=0.3915 | Brier=0.0759
# --> Moyennes | AUC=0.9363 | AP=0.4033 | Brier=0.0650
#
# [187/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 400, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9429 | AP=0.4079 | Brier=0.0385
#   Fold 2 | AUC=0.9457 | AP=0.4432 | Brier=0.0343
#   Fold 3 | AUC=0.9211 | AP=0.3769 | Brier=0.0615
#   Fold 4 | AUC=0.9388 | AP=0.3638 | Brier=0.0590
#   Fold 5 | AUC=0.9228 | AP=0.3836 | Brier=0.0603
# --> Moyennes | AUC=0.9343 | AP=0.3951 | Brier=0.0507
#
# [188/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 400, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9451 | AP=0.4058 | Brier=0.0393
#   Fold 2 | AUC=0.9452 | AP=0.4464 | Brier=0.0350
#   Fold 3 | AUC=0.9226 | AP=0.3868 | Brier=0.0624
#   Fold 4 | AUC=0.9403 | AP=0.3763 | Brier=0.0586
#   Fold 5 | AUC=0.9234 | AP=0.3880 | Brier=0.0604
# --> Moyennes | AUC=0.9353 | AP=0.4007 | Brier=0.0511
#
# [189/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 700, 'num_leaves': 15, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9432 | AP=0.3859 | Brier=0.0412
#   Fold 2 | AUC=0.9453 | AP=0.4532 | Brier=0.0375
#   Fold 3 | AUC=0.9219 | AP=0.3743 | Brier=0.0674
#   Fold 4 | AUC=0.9392 | AP=0.3761 | Brier=0.0645
#   Fold 5 | AUC=0.9217 | AP=0.3899 | Brier=0.0648
# --> Moyennes | AUC=0.9343 | AP=0.3959 | Brier=0.0551
#
# [190/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 700, 'num_leaves': 15, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9436 | AP=0.3871 | Brier=0.0423
#   Fold 2 | AUC=0.9446 | AP=0.4457 | Brier=0.0385
#   Fold 3 | AUC=0.9220 | AP=0.3811 | Brier=0.0691
#   Fold 4 | AUC=0.9396 | AP=0.3692 | Brier=0.0653
#   Fold 5 | AUC=0.9234 | AP=0.3894 | Brier=0.0651
# --> Moyennes | AUC=0.9346 | AP=0.3945 | Brier=0.0560
#
# [191/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 700, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9420 | AP=0.4078 | Brier=0.0392
#   Fold 2 | AUC=0.9454 | AP=0.4248 | Brier=0.0321
#   Fold 3 | AUC=0.9201 | AP=0.3722 | Brier=0.0530
#   Fold 4 | AUC=0.9378 | AP=0.3624 | Brier=0.0504
#   Fold 5 | AUC=0.9215 | AP=0.3739 | Brier=0.0503
# --> Moyennes | AUC=0.9334 | AP=0.3882 | Brier=0.0450
#
# [192/192] Test params: {'class_weight': 'balanced', 'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 700, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}
#   Fold 1 | AUC=0.9431 | AP=0.3952 | Brier=0.0393
#   Fold 2 | AUC=0.9439 | AP=0.4261 | Brier=0.0327
#   Fold 3 | AUC=0.9214 | AP=0.3827 | Brier=0.0529
#   Fold 4 | AUC=0.9393 | AP=0.3659 | Brier=0.0500
#   Fold 5 | AUC=0.9222 | AP=0.3823 | Brier=0.0505
# --> Moyennes | AUC=0.9340 | AP=0.3904 | Brier=0.0451
#
# Meilleurs hyperparamètres trouvés :
# {'class_weight': None, 'colsample_bytree': 0.8, 'learning_rate': 0.03, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 200, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}
#
# Top 10 résultats CV :
#   class_weight  colsample_bytree  learning_rate  max_depth  min_child_samples  \
# 0     balanced               0.8           0.03          6                 50
# 1         None               0.8           0.03         -1                 20
# 2         None               0.8           0.03         -1                 50
# 3         None               0.8           0.03          6                 50
# 4     balanced               0.8           0.03         -1                 50
# 5         None               0.8           0.03         -1                 50
# 6         None               0.8           0.03          6                 50
# 7         None               0.8           0.03         -1                 20
# 8         None               0.8           0.03          6                 20
# 9     balanced               0.8           0.03         -1                 20
#
#    n_estimators  num_leaves  reg_alpha  reg_lambda  subsample  mean_auc  \
# 0           200          31        0.0         1.0        0.8  0.937623
# 1           200          31        0.0         1.0        0.8  0.938042
# 2           200          15        0.0         1.0        0.8  0.938488
# 3           200          31        0.0         1.0        0.8  0.937663
# 4           200          15        0.0         1.0        0.8  0.938339
# 5           200          31        0.0         1.0        0.8  0.938381
# 6           200          15        0.0         1.0        0.8  0.938464
# 7           200          15        0.0         1.0        0.8  0.938294
# 8           200          31        0.0         1.0        0.8  0.937567
# 9           200          15        0.0         1.0        0.8  0.937957
#
#     mean_ap  mean_brier
# 0  0.417290    0.077493
# 1  0.416985    0.032742
# 2  0.416079    0.032582
# 3  0.415988    0.032619
# 4  0.415301    0.084071
# 5  0.415281    0.032671
# 6  0.415211    0.032561
# 7  0.415177    0.032599
# 8  0.414823    0.032695
# 9  0.414661    0.083751

# %%
best_params = {'class_weight': None, 'colsample_bytree': 0.8, 'learning_rate': 0.03, 'max_depth': -1, 'min_child_samples': 20, 
 'n_estimators': 200, 'num_leaves': 31, 'reg_alpha': 0.0, 'reg_lambda': 1.0, 'subsample': 0.8}

# %%
# Out:
# {'class_weight': None,
#  'colsample_bytree': 0.8,
#  'learning_rate': 0.03,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'n_estimators': 200,
#  'num_leaves': 31,
#  'reg_alpha': 0.0,
#  'reg_lambda': 1.0,
#  'subsample': 0.8}

# %%
t0 = time.time()

df_train_feat, strong_cg_threshold = add_base_columns(df_train, strong_cg_threshold=None)
df_valid_feat, _ = add_base_columns(df_valid, strong_cg_threshold=strong_cg_threshold)

# TRAIN
base_train = build_timestamp_features(df_train_feat)
base_time_train = add_since_features(base_train)
features_train = add_rolling_features(base_time_train)
features_train = add_derived_features(features_train)

# VALID
base_valid = build_timestamp_features(df_valid_feat)
base_time_valid = add_since_features(base_valid)
features_valid = add_rolling_features(base_time_valid)
features_valid = add_derived_features(features_valid)

print("Feature build time:", round(time.time() - t0, 2), "s")
print("features_train:", features_train.shape)
print("features_valid:", features_valid.shape)
# Out:
# Feature build time: 12.52 s
# features_train: (400210, 146)
# features_valid: (168170, 146)

# %%
target_train, _ = compute_target_safe_to_end(df_train_feat, danger_dist_km=20)
alert_life_train = compute_alert_life(df_train_feat)
airport_static = compute_airport_static(df_train_feat)

model_df_train = (
    target_train
    .merge(features_train, on=["airport", "date"], how="left")
    .merge(alert_life_train, on=["airport", "airport_alert_id", "date"], how="left")
    .merge(airport_static, on="airport", how="left")
)

model_df_train["airport"] = model_df_train["airport"].astype("category")
if "season" in model_df_train.columns:
    model_df_train["season"] = model_df_train["season"].astype("category")

print(model_df_train.shape)
print(model_df_train["safe_to_end_now"].mean())

target_valid, _ = compute_target_safe_to_end(df_valid_feat, danger_dist_km=20)
alert_life_valid = compute_alert_life(df_valid_feat)



model_df_valid = (
    test_candidates
    .merge(features_valid, on=["airport", "date"], how="left")
    .merge(alert_life_valid, on=["airport", "airport_alert_id", "date"], how="left")
    .merge(airport_static, on="airport", how="left")
)

model_df_valid["airport"] = model_df_valid["airport"].astype("category")
if "season" in model_df_valid.columns:
    model_df_valid["season"] = model_df_valid["season"].astype("category")

print(model_df_valid.shape)

TARGET_COL = "safe_to_end_now"

DROP_COLS = [
    TARGET_COL,
    "date",
    "airport_alert_id",
]

OPTIONAL_DROP_COLS = [
    "lightning_id",
]

X_train = model_df_train.drop(columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in model_df_train.columns], errors="ignore").copy()
y_train = model_df_train[TARGET_COL].astype(int).copy()

cat_cols = X_train.select_dtypes(include=["object", "category"]).columns.tolist()
for c in cat_cols:
    X_train[c] = X_train[c].astype("category")

final_model = LGBMClassifier(**best_params)
final_model.fit(
    X_train,
    y_train,
    categorical_feature=cat_cols if len(cat_cols) > 0 else "auto",
)

print("Entraînement terminé.")
# Out:
# (53753, 163)
# 0.048871690882369354
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 25
#      19 target_valid, _ = compute_target_safe_to_end(df_valid_feat, danger_dist_km=20)
#      20 alert_life_valid = compute_alert_life(df_valid_feat)
#      24 model_df_valid = (
# ---> 25     test_candidates
#      26     .merge(features_valid, on=["airport", "date"], how="left")
#      27     .merge(alert_life_valid, on=["airport", "airport_alert_id", "date"], how="left")
#      28     .merge(airport_static, on="airport", how="left")
#      29 )
#      31 model_df_valid["airport"] = model_df_valid["airport"].astype("category")
#      32 if "season" in model_df_valid.columns:
#
# NameError: name 'test_candidates' is not defined

# %%
target_train, _ = compute_target_safe_to_end(df_train_feat, danger_dist_km=20)
alert_life_train = compute_alert_life(df_train_feat)
airport_static = compute_airport_static(df_train_feat)

model_df_train = (
    target_train
    .merge(features_train, on=["airport", "date"], how="left")
    .merge(alert_life_train, on=["airport", "airport_alert_id", "date"], how="left")
    .merge(airport_static, on="airport", how="left")
)

model_df_train["airport"] = model_df_train["airport"].astype("category")
if "season" in model_df_train.columns:
    model_df_train["season"] = model_df_train["season"].astype("category")

print(model_df_train.shape)
print(model_df_train["safe_to_end_now"].mean())

target_valid, _ = compute_target_safe_to_end(df_valid_feat, danger_dist_km=20)
alert_life_valid = compute_alert_life(df_valid_feat)



model_df_valid = (
    test_candidates
    .merge(features_valid, on=["airport", "date"], how="left")
    .merge(alert_life_valid, on=["airport", "airport_alert_id", "date"], how="left")
    .merge(airport_static, on="airport", how="left")
)

model_df_valid["airport"] = model_df_valid["airport"].astype("category")
if "season" in model_df_valid.columns:
    model_df_valid["season"] = model_df_valid["season"].astype("category")

print(model_df_valid.shape)

TARGET_COL = "safe_to_end_now"

DROP_COLS = [
    TARGET_COL,
    "date",
    "airport_alert_id",
]

OPTIONAL_DROP_COLS = [
    "lightning_id",
]

best_params= {
    "objective": "binary",
    "n_estimators": 500,
    "learning_rate": 0.05,
    "num_leaves": 31,
    "max_depth": -1,
    "min_child_samples": 20,
    "subsample": 0.9,
    "colsample_bytree": 0.9,
    "reg_alpha": 0.0,
    "reg_lambda": 0.0,
    "random_state": 42,
    "n_jobs": -1,
}

X_train = model_df_train.drop(columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in model_df_train.columns], errors="ignore").copy()
y_train = model_df_train[TARGET_COL].astype(int).copy()

cat_cols = X_train.select_dtypes(include=["object", "category"]).columns.tolist()
for c in cat_cols:
    X_train[c] = X_train[c].astype("category")

final_model = LGBMClassifier(**best_params)
final_model.fit(
    X_train,
    y_train,
    categorical_feature=cat_cols if len(cat_cols) > 0 else "auto",
)

print("Entraînement terminé.")
# Out:
# (53753, 163)
# 0.048871690882369354

# %%
X_valid = model_df_valid.drop(columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in model_df_valid.columns], errors="ignore").copy()

for c in cat_cols:
    if c in X_valid.columns:
        X_valid[c] = X_valid[c].astype("category")

missing_cols = [c for c in X_train.columns if c not in X_valid.columns]
extra_cols = [c for c in X_valid.columns if c not in X_train.columns]

print("Missing cols in valid:", missing_cols)
print("Extra cols in valid:", extra_cols)

for c in missing_cols:
    X_valid[c] = 0

d = X_valid[X_train.columns]

valid_pred_proba = final_model.predict_proba(X_valid)[:, 1]

predictions = model_df_valid[["airport", "airport_alert_id", "date"]].copy()
predictions["prediction_date"] = predictions["date"]
predictions["predicted_date_end_alert"] = predictions["date"]
predictions["confidence"] = valid_pred_proba

predictions = predictions[
    ["airport", "airport_alert_id", "prediction_date", "predicted_date_end_alert", "confidence"]
].sort_values(["airport", "airport_alert_id", "prediction_date"]).reset_index(drop=True)

predictions.to_csv("predictions_test.csv", index=False)

print(predictions.head())
print(predictions.shape)
# Out:
# Missing cols in valid: []
# Extra cols in valid: []
#    airport  airport_alert_id           prediction_date  \
# 0  Ajaccio             532.0 2023-01-17 07:17:34+00:00
# 1  Ajaccio             533.0 2023-01-17 10:52:24+00:00
# 2  Ajaccio             534.0 2023-01-17 23:47:55+00:00
# 3  Ajaccio             537.0 2023-03-20 11:04:56+00:00
# 4  Ajaccio             546.0 2023-05-13 21:26:58+00:00
#
#    predicted_date_end_alert  confidence
# 0 2023-01-17 07:17:34+00:00    0.403049
# 1 2023-01-17 10:52:24+00:00    0.295882
# 2 2023-01-17 23:47:55+00:00    0.468656
# 3 2023-03-20 11:04:56+00:00    0.528947
# 4 2023-05-13 21:26:58+00:00    0.577061
# (170433, 5)

# %%
X_valid = model_df_valid.drop(columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in model_df_valid.columns], errors="ignore").copy()

for c in cat_cols:
    if c in X_valid.columns:
        X_valid[c] = X_valid[c].astype("category")

missing_cols = [c for c in X_train.columns if c not in X_valid.columns]
extra_cols = [c for c in X_valid.columns if c not in X_train.columns]

print("Missing cols in valid:", missing_cols)
print("Extra cols in valid:", extra_cols)

for c in missing_cols:
    X_valid[c] = 0



d = X_valid[X_train.columns]

valid_pred_proba = final_model.predict_proba(X_valid)[:, 1]

predictions = model_df_valid[["airport", "airport_alert_id", "date"]].copy()
predictions["prediction_date"] = predictions["date"]
predictions["predicted_date_end_alert"] = predictions["date"]
predictions["confidence"] = valid_pred_proba

predictions = predictions[
    ["airport", "airport_alert_id", "prediction_date", "predicted_date_end_alert", "confidence"]
].sort_values(["airport", "airport_alert_id", "prediction_date"]).reset_index(drop=True)

predictions.to_csv("predictions_test.csv", index=False)

print(predictions.head())
print(predictions.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X_valid = model_df_valid.drop(columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in model_df_valid.columns], errors="ignore").copy()
#       3 for c in cat_cols:
#       4     if c in X_valid.columns:
#
# NameError: name 'model_df_valid' is not defined

# %%
print(pd.Series(valid_pred_proba).describe())

print("Min:", valid_pred_proba.min())
print("Max:", valid_pred_proba.max())

for q in [0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99]:
    print(q, np.quantile(valid_pred_proba, q))
# Out:
# count    170433.000000
# mean          0.110195
# std           0.164895
# min           0.000203
# 25%           0.001637
# 50%           0.018798
# 75%           0.164641
# max           0.923361
# dtype: float64
# Min: 0.00020327285250090998
# Max: 0.9233609344048048
# 0.01 0.00023876709930820716
# 0.05 0.0003242070034299565
# 0.1 0.00039063987288499554
# 0.25 0.0016367619488156624
# 0.5 0.018798243830873772
# 0.75 0.16464057843634114
# 0.9 0.38858141532743656
# 0.95 0.4862223347884219
# 0.99 0.6242050134473466

# %%
import matplotlib.pyplot as plt

plt.hist(valid_pred_proba, bins=50)
plt.xlabel("Predicted probability")
plt.ylabel("Count")
plt.title("Distribution des probabilités prédites")
plt.show()

# %%
eval_valid = (
    target_valid
    .merge(model_df_valid, on=["airport", "airport_alert_id", "date"], how="inner")
)

X_valid_eval = eval_valid.drop(
    columns=[c for c in DROP_COLS + OPTIONAL_DROP_COLS if c in eval_valid.columns],
    errors="ignore"
).copy()

for c in cat_cols:
    if c in X_valid_eval.columns:
        X_valid_eval[c] = X_valid_eval[c].astype("category")

X_valid_eval = X_valid_eval[X_train.columns]

y_valid = eval_valid["safe_to_end_now"].astype(int).values
p_valid = final_model.predict_proba(X_valid_eval)[:, 1]

print("ROC-AUC :", roc_auc_score(y_valid, p_valid))
print("AP      :", average_precision_score(y_valid, p_valid))
print("Brier   :", brier_score_loss(y_valid, p_valid))

print(eval_valid.groupby("safe_to_end_now").apply(lambda g: pd.Series({
    "mean_proba": g["confidence"].mean() if "confidence" in g.columns else np.nan
})))
# Out:
# ROC-AUC : 0.8173518535447534
# AP      : 0.1608761831030665
# Brier   : 0.04048742850278561
#                  mean_proba
# safe_to_end_now
# 0                       NaN
# 1                       NaN
# /tmp/ipykernel_11960/1913605773.py:24: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   print(eval_valid.groupby("safe_to_end_now").apply(lambda g: pd.Series({

# %%
tmp = eval_valid.copy()
tmp["proba"] = p_valid
print(tmp.groupby("safe_to_end_now")["proba"].describe())
# Out:
#                    count      mean       std       min       25%       50%  \
# safe_to_end_now
# 0                12721.0  0.036468  0.082746  0.000203  0.000398  0.003449
# 1                  577.0  0.145652  0.151564  0.000211  0.020154  0.089435
#
#                       75%       max
# safe_to_end_now
# 0                0.024566  0.748484
# 1                0.232062  0.708151
